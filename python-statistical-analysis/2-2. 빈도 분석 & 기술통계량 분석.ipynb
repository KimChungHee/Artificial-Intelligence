# %% [markdown]
# <br>
#
# ## 1. 데이터탐색과 빈도분석 (Pie chart & Bar chart)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('cosmetics_.csv', encoding='utf-8')
df.head()
# Out:
#    gender  marriage  edu  job  mincome  aware  count  amount  decision  \
# 0       1         1    4    1        2      2      1   11000         2
# 1       2         1    4    9        2      1      4   30000         1
# 2       2         2    4    4        3      1      6  100000         3
# 3       2         2    4    7        5      2      6   65000         3
# 4       1         2    6    6        5      2      2   50000         2
#
#    propensity  skin  promo  location  satisf_b  satisf_i  satisf_al  \
# 0           1     1      1         2         5         2          2
# 1           1     3      2         3         2         3          3
# 2           2     3      2         2         4         5          4
# 3           2     5      2         3         3         4          4
# 4           2     3      2         3         3         3          3
#
#    repurchase
# 0           2
# 1           4
# 2           4
# 3           4
# 4           3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df['gender'] = df['gender'].replace([1, 2], ['male', 'female'])
df.head()
# Out:
#    gender  marriage  edu  job  mincome  aware  count  amount  decision  \
# 0    male         1    4    1        2      2      1   11000         2
# 1  female         1    4    9        2      1      4   30000         1
# 2  female         2    4    4        3      1      6  100000         3
# 3  female         2    4    7        5      2      6   65000         3
# 4    male         2    6    6        5      2      2   50000         2
#
#    propensity  skin  promo  location  satisf_b  satisf_i  satisf_al  \
# 0           1     1      1         2         5         2          2
# 1           1     3      2         3         2         3          3
# 2           2     3      2         2         4         5          4
# 3           2     5      2         3         3         4          4
# 4           2     3      2         3         3         3          3
#
#    repurchase
# 0           2
# 1           4
# 2           4
# 3           4
# 4           3

# %%
df['gender'].value_counts()
# Out:
# male      132
# female    115
# Name: gender, dtype: int64

# %%
df['gender'].value_counts().plot(kind = "pie")

# %%
df['gender'].value_counts().plot(kind = "bar")

# %%
df.head()
# Out:
#    gender  marriage  edu  job  mincome  aware  count  amount  decision  \
# 0    male         1    4    1        2      2      1   11000         2
# 1  female         1    4    9        2      1      4   30000         1
# 2  female         2    4    4        3      1      6  100000         3
# 3  female         2    4    7        5      2      6   65000         3
# 4    male         2    6    6        5      2      2   50000         2
#
#    propensity  skin  promo  location  satisf_b  satisf_i  satisf_al  \
# 0           1     1      1         2         5         2          2
# 1           1     3      2         3         2         3          3
# 2           2     3      2         2         4         5          4
# 3           2     5      2         3         3         4          4
# 4           2     3      2         3         3         3          3
#
#    repurchase
# 0           2
# 1           4
# 2           4
# 3           4
# 4           3

# %%
df['marriage'] = df['marriage'].replace([1, 2, 3], ['single', 'married', 'other'])
df['marriage'].value_counts()
# Out:
# married    176
# single      71
# Name: marriage, dtype: int64

# %%
# %matplotlib inline
df['marriage'].value_counts().plot(kind="pie")

# %%
df['marriage'].value_counts().plot(kind="bar")

# %% [markdown]
# <br>
#
# ## 2. 데이터탐색과 기술통계분석

# %% [markdown]
# <br>
#
# #### DataFrame의 기본적인 기술통계량 함수 ('1회 평균 구매 비용'을 기준으로)

# %%
df = pd.read_csv('cosmetics_.csv', encoding='utf-8')

# %%
df['amount'].max() # 가장 높은 [ 1회 평균 구매 비용 ]
# Out:
# 5000000

# %%
df['amount'].min()
# Out:
# 3000

# %%
df['amount'].sum()
# Out:
# 38023000

# %%
df['amount'].mean()
# Out:
# 153939.27125506074

# %%
df['amount'].var()
# Out:
# 158463699549.0602

# %%
df['amount'].std()
# Out:
# 398074.9923683479

# %%
df['amount'].describe()
# Out:
# count    2.470000e+02
# mean     1.539393e+05
# std      3.980750e+05
# min      3.000000e+03
# 25%      3.000000e+04
# 50%      5.200000e+04
# 75%      1.000000e+05
# max      5.000000e+06
# Name: amount, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 17 columns):
# gender        247 non-null int64
# marriage      247 non-null int64
# edu           247 non-null int64
# job           247 non-null int64
# mincome       247 non-null int64
# aware         247 non-null int64
# count         247 non-null int64
# amount        247 non-null int64
# decision      247 non-null int64
# propensity    247 non-null int64
# skin          247 non-null int64
# promo         247 non-null int64
# location      247 non-null int64
# satisf_b      247 non-null int64
# satisf_i      247 non-null int64
# satisf_al     247 non-null int64
# repurchase    247 non-null int64
# dtypes: int64(17)
# memory usage: 32.9 KB

# %% [markdown]
# <br>
#
# #### 분포의 왜도와 첨도

# %%
df['amount'].hist() # 1회 평균 구매 비용

# %%
df['amount'].skew() # 왜도, 분포에서 긴 꼬리가 왼쪽에 있으면 음(negative)의 왜도, 그 반대의 경우 양(positive)의 왜도를 가진다고 한다.
# Out:
# 8.727245406515182

# %%
df['amount'].kurtosis() # 첨도, 분포의 뾰족한 정도
# Out:
# 94.95150601199587

# %%
df['decision'].hist() # 구매 요인 (사회적 요인, 심리적 요인, 외모적 요인)

# %%
df['decision'].skew() # 왜도, 분포에서 긴 꼬리가 왼쪽에 있으면 음(negative)의 왜도, 그 반대의 경우 양(positive)의 왜도를 가진다고 한다.
# Out:
# -0.7874015776363626

# %%
df['job'].hist()

# %%
df['job'].kurtosis() # 첨도, 분포의 뾰족한 정도
# Out:
# -0.12032961249934582

# %% [markdown]
# <br>
#
# #### Histogram & Distribution plot & Joint plot ('연 구매 횟수'와 '1회 평균 구매 비용'을 기준으로)

# %%
df.describe()
# Out:
#            gender    marriage         edu         job     mincome       aware  \
# count  247.000000  247.000000  247.000000  247.000000  247.000000  247.000000
# mean     1.465587    1.712551    4.566802    4.578947    3.757085    3.319838
# std      0.499827    0.453492    1.709191    2.199603    1.674079    5.575692
# min      1.000000    1.000000    2.000000    1.000000    1.000000    1.000000
# 25%      1.000000    1.000000    4.000000    3.000000    2.000000    1.000000
# 50%      1.000000    2.000000    4.000000    4.000000    4.000000    2.000000
# 75%      2.000000    2.000000    6.000000    6.000000    5.000000    2.000000
# max      2.000000    2.000000    8.000000   10.000000    6.000000   31.000000
#
#             count        amount    decision  propensity        skin  \
# count  247.000000  2.470000e+02  247.000000  247.000000  247.000000
# mean     4.327935  1.539393e+05    2.388664    1.975709    2.761134
# std      4.422061  3.980750e+05    0.761599    0.680310    1.488311
# min      1.000000  3.000000e+03    1.000000    1.000000    1.000000
# 25%      2.000000  3.000000e+04    2.000000    2.000000    1.000000
# 50%      3.000000  5.200000e+04    3.000000    2.000000    3.000000
# 75%      5.000000  1.000000e+05    3.000000    2.000000    4.000000
# max     36.000000  5.000000e+06    3.000000    3.000000    5.000000
#
#             promo    location    satisf_b    satisf_i   satisf_al  repurchase
# count  247.000000  247.000000  247.000000  247.000000  247.000000  247.000000
# mean     2.016194    2.465587    2.890688    3.404858    3.461538    3.554656
# std      0.821300    1.073437    0.780995    0.830110    0.752731    0.724182
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      2.000000    2.000000    2.000000    3.000000    3.000000    3.000000
# 50%      2.000000    3.000000    3.000000    3.000000    4.000000    4.000000
# 75%      2.000000    3.000000    3.000000    4.000000    4.000000    4.000000
# max      4.000000    5.000000    5.000000    5.000000    5.000000    5.000000

# %%
df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B11199FEB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B111A01EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B111A2D160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B111A583C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001B111A80630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B111AA9898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B111AD1B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B111AFBDA0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001B111AFBDD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B111B56278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B111B7E4E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B111BA6748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001B111BD19B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B111BF8C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B111C22E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B111C53128>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001B111C7C390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B111CA7748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B111CCECC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B111CFF278>]],
#       dtype=object)

# %%
df_amount=df['amount'] # 1회 평균 구매 비용
df_amount.hist(bins=50, figsize=(20,15))

# %%
df_count=df['count'] # 연 구매 횟수
df_count.hist(bins=50, figsize=(20,15))

# %%
import seaborn as sns

sns.distplot(df_amount, rug=True) # distribution plot

# %%
sns.jointplot(x="amount", y="count", data=df) # 산점도와 히스토그램을 한번에

# %%
sns.jointplot(x="amount", y="count", data=df, kind="kde") # Kernel-density (커널이라는 함수를 겹치는 방법으로 히스토그램보다 부드러운 형태의 분포 곡선을 보여주는 방법)

# 꼬리가 너무 긴 형태의 분포 -> 이상치가 분포를 제대로 확인하는 것을 방해하고 있을 수 있음

# %% [markdown]
# <br>
#
# ## 3. Outlier 의 탐지 및 제거와 전후 분포 비교

# %%
df.boxplot(column='amount') # 위 아래의 작은 검정색 선이 상/하한선, 그 밖의 경우는 Outlier (동그라미로 표시해 줌)

# %%
df['amount'].describe()
# Out:
# count    2.470000e+02
# mean     1.539393e+05
# std      3.980750e+05
# min      3.000000e+03
# 25%      3.000000e+04
# 50%      5.200000e+04
# 75%      1.000000e+05
# max      5.000000e+06
# Name: amount, dtype: float64

# %%
df['amount'].quantile() # 사분위수를 돌려주는 함수, default == 0.5
# Out:
# 52000.0

# %%
df['amount'].median() # 중위값
# Out:
# 52000.0

# %%
# Inter-Quantile == 바닥부터 75% 지점의 값 - 바닥부터 25% 지점의 값

Q1 = df['amount'].quantile(q = 0.25)
Q3 = df['amount'].quantile(q = 0.75)

IQR = Q3 - Q1
IQR
# Out:
# 70000.0

# %%
# 상한치 : 바닥부터 75% 지점의 값 + IQR의 1.5배 
# 하한치 : 바닥부터 25% 지점의 값 - IQR의 1.5배 
# 그 기준을 넘기면 Outlier로 판단이 가능 

df_IQR = df[ (df['amount'] < Q3 + IQR * 1.5) & (df['amount'] > Q1 - IQR * 1.5) ]

# %%
df_IQR.boxplot(column='amount') # 위 아래의 작은 검정색 선이 상/하한선, 그 밖의 경우는 Outlier (동그라미로 표시해 줌)

# %%
df.boxplot(column='count') # 위 아래의 작은 검정색 선이 상/하한선, 그 밖의 경우는 Outlier (동그라미로 표시해 줌)

# %%
processed_df = df[['amount', 'count']]
processed_df = processed_df[ (processed_df['count'] < 10) & (processed_df['amount'] < 200000) ] # 상한선에 해당하는 값

processed_df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B116B03D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B119576A20>]],
#       dtype=object)

# %%
df[['amount', 'count']].hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B116DCF320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B116B7B6A0>]],
#       dtype=object)

# %%
sns.jointplot(x="amount", y="count", data=processed_df)

# %%
sns.jointplot(x="amount", y="count", data=df)

# %% [markdown]
# <br>
#
# #### Log 함수를 활용한 Data Scaling

# %%
Min-Max algo -> 
standatdization -> mean(열) : 0, std(열) : 1

# %%
sns.jointplot(x="amount", y="count", data=processed_df, kind="kde")

# count에 비해 amount의 Scale이 너무 큰 상태

# %%
processed_df['logamount'] = np.log(processed_df['amount'])

# %%
sns.jointplot(x="logamount", y="count", data=processed_df, kind="kde")
